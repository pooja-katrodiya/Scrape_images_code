# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# Out:
# C:\Users\kruta\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\kruta\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\kruta\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('C:\\Users\\kruta\\Downloads\\Step1234') 

# Actions that we try to detect
actions = np.array(['thank you','hello','What'])

# # Thirty videos worth of data
no_sequences = 30

# # Videos are going to be 30 frames in length
sequence_length = 30

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'thank you': 0, 'hello': 1, 'What': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (90,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 3s 55ms/step - loss: 1.2366 - categorical_accuracy: 0.3412
# Epoch 2/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 7.8061 - categorical_accuracy: 0.2941
# Epoch 3/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 11.2156 - categorical_accuracy: 0.3059
# Epoch 4/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 8.6162 - categorical_accuracy: 0.3529
# Epoch 5/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 5.0483 - categorical_accuracy: 0.2706
# Epoch 6/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 4.2714 - categorical_accuracy: 0.3529
# Epoch 7/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 6.4297 - categorical_accuracy: 0.2941
# Epoch 8/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 3.6690 - categorical_accuracy: 0.4471
# Epoch 9/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 9.1815 - categorical_accuracy: 0.3765
# Epoch 10/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 9.1242 - categorical_accuracy: 0.5059
# Epoch 11/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 7.2374 - categorical_accuracy: 0.3647
# Epoch 12/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 8.8634 - categorical_accuracy: 0.2235
# Epoch 13/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 13.0852 - categorical_accuracy: 0.2588
# Epoch 14/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 10.9398 - categorical_accuracy: 0.2235
# Epoch 15/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 11.2433 - categorical_accuracy: 0.2000
# Epoch 16/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 15.9044 - categorical_accuracy: 0.3176
# Epoch 17/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 9.4077 - categorical_accuracy: 0.3412
# Epoch 18/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 12.5710 - categorical_accuracy: 0.3294
# Epoch 19/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 35.5401 - categorical_accuracy: 0.3412
# Epoch 20/2000
# 3/3 [==============================] - 0s 53ms/step - loss: 58.7280 - categorical_accuracy: 0.3294
# Epoch 21/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 236.3024 - categorical_accuracy: 0.2706
# Epoch 22/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 208.0728 - categorical_accuracy: 0.3059
# Epoch 23/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1241.4287 - categorical_accuracy: 0.3294
# Epoch 24/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 2022.1704 - categorical_accuracy: 0.3529
# Epoch 25/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 966.6155 - categorical_accuracy: 0.3412
# Epoch 26/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 804.8684 - categorical_accuracy: 0.2824
# Epoch 27/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 677.4142 - categorical_accuracy: 0.4000
# Epoch 28/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1019.9862 - categorical_accuracy: 0.4000
# Epoch 29/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 802.1445 - categorical_accuracy: 0.3059
# Epoch 30/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1151.9191 - categorical_accuracy: 0.3412
# Epoch 31/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 585.1744 - categorical_accuracy: 0.4235
# Epoch 32/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 894.0089 - categorical_accuracy: 0.3294
# Epoch 33/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 511.5870 - categorical_accuracy: 0.3059
# Epoch 34/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 643.9417 - categorical_accuracy: 0.3412
# Epoch 35/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1082.6021 - categorical_accuracy: 0.3529
# Epoch 36/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1470.2001 - categorical_accuracy: 0.3647
# Epoch 37/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 982.2188 - categorical_accuracy: 0.3412
# Epoch 38/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1562.9757 - categorical_accuracy: 0.3176
# Epoch 39/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1058.8131 - categorical_accuracy: 0.2824
# Epoch 40/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 469.7407 - categorical_accuracy: 0.4000
# Epoch 41/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1303.0968 - categorical_accuracy: 0.3529
# Epoch 42/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 983.2263 - categorical_accuracy: 0.4000
# Epoch 43/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 1868.5931 - categorical_accuracy: 0.2471
# Epoch 44/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 1744.5353 - categorical_accuracy: 0.3529
# Epoch 45/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 907.9504 - categorical_accuracy: 0.2235
# Epoch 46/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 719.4279 - categorical_accuracy: 0.3529
# Epoch 47/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 568.3904 - categorical_accuracy: 0.3647
# Epoch 48/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 393.3783 - categorical_accuracy: 0.5059
# Epoch 49/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 437.6223 - categorical_accuracy: 0.3294
# Epoch 50/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 770.5085 - categorical_accuracy: 0.3412
# Epoch 51/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 605.7563 - categorical_accuracy: 0.3176
# Epoch 52/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 351.4376 - categorical_accuracy: 0.3529
# Epoch 53/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 675.8524 - categorical_accuracy: 0.4235
# Epoch 54/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 873.7239 - categorical_accuracy: 0.2471
# Epoch 55/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 560.3401 - categorical_accuracy: 0.3176
# Epoch 56/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 275.3796 - categorical_accuracy: 0.3294
# Epoch 57/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 295.3602 - categorical_accuracy: 0.2588
# Epoch 58/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 196.6150 - categorical_accuracy: 0.4235
# Epoch 59/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 137.4303 - categorical_accuracy: 0.3059
# Epoch 60/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 221.8627 - categorical_accuracy: 0.2824
# Epoch 61/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 170.3418 - categorical_accuracy: 0.2706
# Epoch 62/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 287.1559 - categorical_accuracy: 0.2706
# Epoch 63/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 241.2901 - categorical_accuracy: 0.3647
# Epoch 64/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 262.4331 - categorical_accuracy: 0.3529
# Epoch 65/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 232.4109 - categorical_accuracy: 0.3176
# Epoch 66/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 117.1651 - categorical_accuracy: 0.3647
# Epoch 67/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 124.1975 - categorical_accuracy: 0.2941
# Epoch 68/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 183.6574 - categorical_accuracy: 0.3765
# Epoch 69/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 110.4879 - categorical_accuracy: 0.3882
# Epoch 70/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 414.5523 - categorical_accuracy: 0.3294
# Epoch 71/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 227.0581 - categorical_accuracy: 0.2235
# Epoch 72/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 190.5214 - categorical_accuracy: 0.3412
# Epoch 73/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 579.9664 - categorical_accuracy: 0.3176
# Epoch 74/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 201.3086 - categorical_accuracy: 0.4353
# Epoch 75/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 268.2791 - categorical_accuracy: 0.3647
# Epoch 76/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 170.8766 - categorical_accuracy: 0.3647
# Epoch 77/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 208.8248 - categorical_accuracy: 0.3647
# Epoch 78/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 128.8634 - categorical_accuracy: 0.3529
# Epoch 79/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 98.5656 - categorical_accuracy: 0.3412
# Epoch 80/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 124.1643 - categorical_accuracy: 0.3882
# Epoch 81/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 178.0443 - categorical_accuracy: 0.2471
# Epoch 82/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 213.8101 - categorical_accuracy: 0.3765
# Epoch 83/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 197.5588 - categorical_accuracy: 0.2706
# Epoch 84/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 259.7001 - categorical_accuracy: 0.3176
# Epoch 85/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 220.7954 - categorical_accuracy: 0.2706
# Epoch 86/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 58.6608 - categorical_accuracy: 0.3412
# Epoch 87/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 50.0090 - categorical_accuracy: 0.2941
# Epoch 88/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 62.2801 - categorical_accuracy: 0.2824
# Epoch 89/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 114.8602 - categorical_accuracy: 0.4000
# Epoch 90/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 96.8811 - categorical_accuracy: 0.3529
# Epoch 91/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 117.0701 - categorical_accuracy: 0.3176
# Epoch 92/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 123.3698 - categorical_accuracy: 0.3294
# Epoch 93/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 79.1752 - categorical_accuracy: 0.2588
# Epoch 94/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 108.7083 - categorical_accuracy: 0.2824
# Epoch 95/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 37.1084 - categorical_accuracy: 0.2941
# Epoch 96/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 34.0605 - categorical_accuracy: 0.3176
# Epoch 97/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 110.0439 - categorical_accuracy: 0.2588
# Epoch 98/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 47.2860 - categorical_accuracy: 0.3294
# Epoch 99/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 54.9081 - categorical_accuracy: 0.2941
# Epoch 100/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 49.0701 - categorical_accuracy: 0.3176
# Epoch 101/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 91.4466 - categorical_accuracy: 0.3529
# Epoch 102/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 98.6535 - categorical_accuracy: 0.3647
# Epoch 103/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 158.2478 - categorical_accuracy: 0.3412
# Epoch 104/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 160.7455 - categorical_accuracy: 0.2824
# Epoch 105/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 83.5793 - categorical_accuracy: 0.3647
# Epoch 106/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 132.5108 - categorical_accuracy: 0.3059
# Epoch 107/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 121.4913 - categorical_accuracy: 0.3412
# Epoch 108/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 145.4686 - categorical_accuracy: 0.3529
# Epoch 109/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 64.5506 - categorical_accuracy: 0.2941
# Epoch 110/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 99.4427 - categorical_accuracy: 0.2824
# Epoch 111/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 76.2762 - categorical_accuracy: 0.3412
# Epoch 112/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 139.0457 - categorical_accuracy: 0.2471
# Epoch 113/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 130.7385 - categorical_accuracy: 0.3412
# Epoch 114/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 80.3084 - categorical_accuracy: 0.3059
# Epoch 115/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 157.0259 - categorical_accuracy: 0.3294
# Epoch 116/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 144.4276 - categorical_accuracy: 0.4000
# Epoch 117/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 50.9620 - categorical_accuracy: 0.3294
# Epoch 118/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 42.9655 - categorical_accuracy: 0.3529
# Epoch 119/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 59.9182 - categorical_accuracy: 0.3176
# Epoch 120/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 97.7358 - categorical_accuracy: 0.3176
# Epoch 121/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 149.8854 - categorical_accuracy: 0.2941
# Epoch 122/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 65.7514 - categorical_accuracy: 0.3294
# Epoch 123/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 70.9217 - categorical_accuracy: 0.3529
# Epoch 124/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 60.7673 - categorical_accuracy: 0.3412
# Epoch 125/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 63.5610 - categorical_accuracy: 0.3059
# Epoch 126/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 81.3737 - categorical_accuracy: 0.3176
# Epoch 127/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 73.4273 - categorical_accuracy: 0.3765
# Epoch 128/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 65.3906 - categorical_accuracy: 0.3765
# Epoch 129/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 54.7897 - categorical_accuracy: 0.3412
# Epoch 130/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 46.6276 - categorical_accuracy: 0.3059
# Epoch 131/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 45.2300 - categorical_accuracy: 0.2588
# Epoch 132/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 34.2404 - categorical_accuracy: 0.3412
# Epoch 133/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 23.3345 - categorical_accuracy: 0.4118
# Epoch 134/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 37.3643 - categorical_accuracy: 0.3647
# Epoch 135/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 73.5231 - categorical_accuracy: 0.2941
# Epoch 136/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 26.0889 - categorical_accuracy: 0.3412
# Epoch 137/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 50.0187 - categorical_accuracy: 0.3059
# Epoch 138/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 62.0689 - categorical_accuracy: 0.3059
# Epoch 139/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 85.3327 - categorical_accuracy: 0.3529
# Epoch 140/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 112.6776 - categorical_accuracy: 0.3294
# Epoch 141/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 67.1356 - categorical_accuracy: 0.3529
# Epoch 142/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 41.7799 - categorical_accuracy: 0.4000
# Epoch 143/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 44.2542 - categorical_accuracy: 0.3176
# Epoch 144/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 14.5461 - categorical_accuracy: 0.2706
# Epoch 145/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 48.0109 - categorical_accuracy: 0.3647
# Epoch 146/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 25.3180 - categorical_accuracy: 0.3529
# Epoch 147/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 64.7168 - categorical_accuracy: 0.3529
# Epoch 148/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 84.9277 - categorical_accuracy: 0.3412
# Epoch 149/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 81.3939 - categorical_accuracy: 0.3294
# Epoch 150/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 32.7657 - categorical_accuracy: 0.3176
# Epoch 151/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 41.1198 - categorical_accuracy: 0.3529
# Epoch 152/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 33.0276 - categorical_accuracy: 0.3412
# Epoch 153/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 64.3970 - categorical_accuracy: 0.3412
# Epoch 154/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 20.2486 - categorical_accuracy: 0.2353
# Epoch 155/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 15.2221 - categorical_accuracy: 0.3882
# Epoch 156/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 22.3585 - categorical_accuracy: 0.3059
# Epoch 157/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 63.1610 - categorical_accuracy: 0.2706
# Epoch 158/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 35.5876 - categorical_accuracy: 0.3882
# Epoch 159/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 63.1538 - categorical_accuracy: 0.3529
# Epoch 160/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 91.2121 - categorical_accuracy: 0.2824
# Epoch 161/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 106.7885 - categorical_accuracy: 0.3294
# Epoch 162/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 64.9866 - categorical_accuracy: 0.3529
# Epoch 163/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 116.8017 - categorical_accuracy: 0.3059
# Epoch 164/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 91.9407 - categorical_accuracy: 0.2941
# Epoch 165/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 79.4660 - categorical_accuracy: 0.4118
# Epoch 166/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 102.4304 - categorical_accuracy: 0.3529
# Epoch 167/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 38.7901 - categorical_accuracy: 0.3529
# Epoch 168/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 82.7941 - categorical_accuracy: 0.2706
# Epoch 169/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 61.1952 - categorical_accuracy: 0.3294
# Epoch 170/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 34.0527 - categorical_accuracy: 0.3765
# Epoch 171/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 55.2631 - categorical_accuracy: 0.2824
# Epoch 172/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 78.9204 - categorical_accuracy: 0.3294
# Epoch 173/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 48.7801 - categorical_accuracy: 0.4000
# Epoch 174/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 49.9481 - categorical_accuracy: 0.2706
# Epoch 175/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 48.3215 - categorical_accuracy: 0.3647
# Epoch 176/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 18.4083 - categorical_accuracy: 0.3647
# Epoch 177/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 32.4084 - categorical_accuracy: 0.3647
# Epoch 178/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 49.8013 - categorical_accuracy: 0.2588
# Epoch 179/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 40.0572 - categorical_accuracy: 0.3529
# Epoch 180/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 42.1323 - categorical_accuracy: 0.2824
# Epoch 181/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 95.6522 - categorical_accuracy: 0.4118
# Epoch 182/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 60.8141 - categorical_accuracy: 0.3294
# Epoch 183/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 46.7088 - categorical_accuracy: 0.3059
# Epoch 184/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 49.4658 - categorical_accuracy: 0.3412
# Epoch 185/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 43.5209 - categorical_accuracy: 0.3765
# Epoch 186/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 38.6048 - categorical_accuracy: 0.3765
# Epoch 187/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 67.4792 - categorical_accuracy: 0.2706
# Epoch 188/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 37.1868 - categorical_accuracy: 0.3176
# Epoch 189/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 65.0901 - categorical_accuracy: 0.3647
# Epoch 190/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 75.1261 - categorical_accuracy: 0.3412
# Epoch 191/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 74.5872 - categorical_accuracy: 0.3176
# Epoch 192/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 67.4776 - categorical_accuracy: 0.2118
# Epoch 193/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 95.1270 - categorical_accuracy: 0.3176
# Epoch 194/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 47.6503 - categorical_accuracy: 0.3529
# Epoch 195/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 68.0485 - categorical_accuracy: 0.3294
# Epoch 196/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 37.5105 - categorical_accuracy: 0.3647
# Epoch 197/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 93.4264 - categorical_accuracy: 0.3529
# Epoch 198/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 90.8264 - categorical_accuracy: 0.3176
# Epoch 199/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 33.0984 - categorical_accuracy: 0.4588
# Epoch 200/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 121.9934 - categorical_accuracy: 0.4235
# Epoch 201/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 105.3738 - categorical_accuracy: 0.3647
# Epoch 202/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 68.3994 - categorical_accuracy: 0.3176
# Epoch 203/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 110.1645 - categorical_accuracy: 0.2471
# Epoch 204/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 62.9960 - categorical_accuracy: 0.2353
# Epoch 205/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 97.2712 - categorical_accuracy: 0.2706
# Epoch 206/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 49.8459 - categorical_accuracy: 0.2235
# Epoch 207/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 78.4723 - categorical_accuracy: 0.3294
# Epoch 208/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 67.8487 - categorical_accuracy: 0.2941
# Epoch 209/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 58.4778 - categorical_accuracy: 0.3059
# Epoch 210/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 85.1454 - categorical_accuracy: 0.3529
# Epoch 211/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 46.6233 - categorical_accuracy: 0.4235
# Epoch 212/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 44.4766 - categorical_accuracy: 0.4471
# Epoch 213/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 44.1535 - categorical_accuracy: 0.3882
# Epoch 214/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 32.7335 - categorical_accuracy: 0.3765
# Epoch 215/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 41.8530 - categorical_accuracy: 0.3294
# Epoch 216/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 42.5675 - categorical_accuracy: 0.3059
# Epoch 217/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 23.3344 - categorical_accuracy: 0.4588
# Epoch 218/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 32.1719 - categorical_accuracy: 0.4000
# Epoch 219/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 29.3768 - categorical_accuracy: 0.3529
# Epoch 220/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 13.6787 - categorical_accuracy: 0.4118
# Epoch 221/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 50.3214 - categorical_accuracy: 0.3647
# Epoch 222/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 52.1426 - categorical_accuracy: 0.3529
# Epoch 223/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 96.9475 - categorical_accuracy: 0.2588
# Epoch 224/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 75.1966 - categorical_accuracy: 0.3059
# Epoch 225/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 74.3636 - categorical_accuracy: 0.4588
# Epoch 226/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 100.2897 - categorical_accuracy: 0.2941
# Epoch 227/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 67.3486 - categorical_accuracy: 0.2941
# Epoch 228/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 104.9518 - categorical_accuracy: 0.3294
# Epoch 229/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 53.0241 - categorical_accuracy: 0.3059
# Epoch 230/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 86.6220 - categorical_accuracy: 0.3176
# Epoch 231/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 53.7610 - categorical_accuracy: 0.2941
# Epoch 232/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 117.6399 - categorical_accuracy: 0.3294
# Epoch 233/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 54.0554 - categorical_accuracy: 0.4235
# Epoch 234/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 36.1657 - categorical_accuracy: 0.3176
# Epoch 235/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 37.5645 - categorical_accuracy: 0.3647
# Epoch 236/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 42.2328 - categorical_accuracy: 0.3176
# Epoch 237/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 70.0639 - categorical_accuracy: 0.3294
# Epoch 238/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 54.4923 - categorical_accuracy: 0.2824
# Epoch 239/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 31.1885 - categorical_accuracy: 0.3882
# Epoch 240/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 23.6491 - categorical_accuracy: 0.3647
# Epoch 241/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 19.7345 - categorical_accuracy: 0.3647
# Epoch 242/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 16.4413 - categorical_accuracy: 0.3647
# Epoch 243/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 25.0183 - categorical_accuracy: 0.3647
# Epoch 244/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 39.3697 - categorical_accuracy: 0.3294
# Epoch 245/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 37.6499 - categorical_accuracy: 0.3647
# Epoch 246/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 52.3075 - categorical_accuracy: 0.3647
# Epoch 247/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 23.0471 - categorical_accuracy: 0.4471
# Epoch 248/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 42.8942 - categorical_accuracy: 0.3294
# Epoch 249/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 24.3450 - categorical_accuracy: 0.4000
# Epoch 250/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 15.9477 - categorical_accuracy: 0.3529
# Epoch 251/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 14.9907 - categorical_accuracy: 0.3647
# Epoch 252/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 20.8379 - categorical_accuracy: 0.3529
# Epoch 253/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 26.0296 - categorical_accuracy: 0.4000
# Epoch 254/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 52.0524 - categorical_accuracy: 0.3529
# Epoch 255/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 38.3055 - categorical_accuracy: 0.3882
# Epoch 256/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 30.6583 - categorical_accuracy: 0.3176
# Epoch 257/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 47.6106 - categorical_accuracy: 0.2353
# Epoch 258/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 44.8279 - categorical_accuracy: 0.3294
# Epoch 259/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 39.1066 - categorical_accuracy: 0.3765
# Epoch 260/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 34.2425 - categorical_accuracy: 0.3059
# Epoch 261/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 21.5330 - categorical_accuracy: 0.3647
# Epoch 262/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 24.2470 - categorical_accuracy: 0.2235
# Epoch 263/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 22.7474 - categorical_accuracy: 0.3412
# Epoch 264/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 43.8617 - categorical_accuracy: 0.2588
# Epoch 265/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 38.2635 - categorical_accuracy: 0.3529
# Epoch 266/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 85.0868 - categorical_accuracy: 0.2941
# Epoch 267/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 51.2934 - categorical_accuracy: 0.3294
# Epoch 268/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 78.9258 - categorical_accuracy: 0.3529
# Epoch 269/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 50.1742 - categorical_accuracy: 0.3176
# Epoch 270/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 104.8173 - categorical_accuracy: 0.3176
# Epoch 271/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 33.3625 - categorical_accuracy: 0.3412
# Epoch 272/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 49.1303 - categorical_accuracy: 0.3765
# Epoch 273/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 30.6635 - categorical_accuracy: 0.3294
# Epoch 274/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 59.3482 - categorical_accuracy: 0.3176
# Epoch 275/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 54.8944 - categorical_accuracy: 0.3647
# Epoch 276/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 70.7126 - categorical_accuracy: 0.3176
# Epoch 277/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 70.1371 - categorical_accuracy: 0.3176
# Epoch 278/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 63.0983 - categorical_accuracy: 0.3294
# Epoch 279/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 49.7931 - categorical_accuracy: 0.3412
# Epoch 280/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 24.7217 - categorical_accuracy: 0.3059
# Epoch 281/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 38.9057 - categorical_accuracy: 0.3412
# Epoch 282/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 21.6094 - categorical_accuracy: 0.4118
# Epoch 283/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 50.9227 - categorical_accuracy: 0.3176
# Epoch 284/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 36.0934 - categorical_accuracy: 0.3412
# Epoch 285/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 17.9028 - categorical_accuracy: 0.3765
# Epoch 286/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 28.7868 - categorical_accuracy: 0.3176
# Epoch 287/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 31.3663 - categorical_accuracy: 0.3765
# Epoch 288/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 29.4970 - categorical_accuracy: 0.3412
# Epoch 289/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 58.8872 - categorical_accuracy: 0.3059
# Epoch 290/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 50.9835 - categorical_accuracy: 0.2941
# Epoch 291/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 45.5052 - categorical_accuracy: 0.4118
# Epoch 292/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 38.3777 - categorical_accuracy: 0.3647
# Epoch 293/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 34.9662 - categorical_accuracy: 0.2941
# Epoch 294/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 19.7508 - categorical_accuracy: 0.4000
# Epoch 295/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 17.4801 - categorical_accuracy: 0.3176
# Epoch 296/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 14.1847 - categorical_accuracy: 0.3176
# Epoch 297/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 26.3486 - categorical_accuracy: 0.3647
# Epoch 298/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 50.7088 - categorical_accuracy: 0.2941
# Epoch 299/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 34.3989 - categorical_accuracy: 0.2471
# Epoch 300/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 46.9139 - categorical_accuracy: 0.4000
# Epoch 301/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 39.4480 - categorical_accuracy: 0.3059
# Epoch 302/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 56.0100 - categorical_accuracy: 0.3412
# Epoch 303/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 71.1750 - categorical_accuracy: 0.3529
# Epoch 304/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 58.5876 - categorical_accuracy: 0.3176
# Epoch 305/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 79.3319 - categorical_accuracy: 0.3059
# Epoch 306/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 35.5733 - categorical_accuracy: 0.3059
# Epoch 307/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 40.8022 - categorical_accuracy: 0.3882
# Epoch 308/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 29.2032 - categorical_accuracy: 0.3059
# Epoch 309/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 32.9924 - categorical_accuracy: 0.3529
# Epoch 310/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 30.6246 - categorical_accuracy: 0.2588
# Epoch 311/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 52.4714 - categorical_accuracy: 0.3882
# Epoch 312/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 44.3922 - categorical_accuracy: 0.3294
# Epoch 313/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 64.1654 - categorical_accuracy: 0.3412
# Epoch 314/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 50.1682 - categorical_accuracy: 0.3059
# Epoch 315/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 46.5232 - categorical_accuracy: 0.3529
# Epoch 316/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 43.1142 - categorical_accuracy: 0.3294
# Epoch 317/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 55.7440 - categorical_accuracy: 0.2471
# Epoch 318/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 51.3978 - categorical_accuracy: 0.2824
# Epoch 319/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 37.0167 - categorical_accuracy: 0.3294
# Epoch 320/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 38.6182 - categorical_accuracy: 0.3294
# Epoch 321/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 25.9094 - categorical_accuracy: 0.3647
# Epoch 322/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 37.0422 - categorical_accuracy: 0.3176
# Epoch 323/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 30.0157 - categorical_accuracy: 0.3765
# Epoch 324/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 43.6489 - categorical_accuracy: 0.3059
# Epoch 325/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 56.4180 - categorical_accuracy: 0.2824
# Epoch 326/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 23.9517 - categorical_accuracy: 0.4353
# Epoch 327/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 44.1004 - categorical_accuracy: 0.3176
# Epoch 328/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 26.7708 - categorical_accuracy: 0.3882
# Epoch 329/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 33.6688 - categorical_accuracy: 0.3765
# Epoch 330/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 26.4060 - categorical_accuracy: 0.2824
# Epoch 331/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 36.0910 - categorical_accuracy: 0.4353
# Epoch 332/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 35.3971 - categorical_accuracy: 0.3765
# Epoch 333/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 55.3912 - categorical_accuracy: 0.3059
# Epoch 334/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 46.1081 - categorical_accuracy: 0.4000
# Epoch 335/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 64.7497 - categorical_accuracy: 0.3765
# Epoch 336/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 42.7013 - categorical_accuracy: 0.3412
# Epoch 337/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 29.8379 - categorical_accuracy: 0.3412
# Epoch 338/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 44.1340 - categorical_accuracy: 0.3647
# Epoch 339/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 48.7981 - categorical_accuracy: 0.2706
# Epoch 340/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 30.1526 - categorical_accuracy: 0.3176
# Epoch 341/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 22.2022 - categorical_accuracy: 0.3412
# Epoch 342/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 25.8131 - categorical_accuracy: 0.3765
# Epoch 343/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 44.6731 - categorical_accuracy: 0.3176
# Epoch 344/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 33.2410 - categorical_accuracy: 0.3529
# Epoch 345/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 37.7309 - categorical_accuracy: 0.2941
# Epoch 346/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 36.3047 - categorical_accuracy: 0.3412
# Epoch 347/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 21.0246 - categorical_accuracy: 0.3529
# Epoch 348/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 34.3829 - categorical_accuracy: 0.3412
# Epoch 349/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 17.1273 - categorical_accuracy: 0.3412
# Epoch 350/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 22.5949 - categorical_accuracy: 0.3529
# Epoch 351/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 17.2951 - categorical_accuracy: 0.3294
# Epoch 352/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 22.6563 - categorical_accuracy: 0.3412
# Epoch 353/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 33.4333 - categorical_accuracy: 0.2824
# Epoch 354/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 20.7485 - categorical_accuracy: 0.3529
# Epoch 355/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 16.8607 - categorical_accuracy: 0.3529
# Epoch 356/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 27.5021 - categorical_accuracy: 0.3059
# Epoch 357/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 22.2324 - categorical_accuracy: 0.3765
# Epoch 358/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 28.3846 - categorical_accuracy: 0.3412
# Epoch 359/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 50.6053 - categorical_accuracy: 0.3765
# Epoch 360/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 45.7742 - categorical_accuracy: 0.3176
# Epoch 361/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 33.0306 - categorical_accuracy: 0.2824
# Epoch 362/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 16.8932 - categorical_accuracy: 0.3647
# Epoch 363/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 18.1523 - categorical_accuracy: 0.3882
# Epoch 364/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 25.9224 - categorical_accuracy: 0.3765
# Epoch 365/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 21.5503 - categorical_accuracy: 0.3529
# Epoch 366/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 12.3182 - categorical_accuracy: 0.3647
# Epoch 367/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 21.7451 - categorical_accuracy: 0.3765
# Epoch 368/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 16.6446 - categorical_accuracy: 0.3294
# Epoch 369/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 20.3580 - categorical_accuracy: 0.3294
# Epoch 370/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 13.5997 - categorical_accuracy: 0.3294
# Epoch 371/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 17.6430 - categorical_accuracy: 0.2941
# Epoch 372/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 21.0800 - categorical_accuracy: 0.3882
# Epoch 373/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 26.4664 - categorical_accuracy: 0.2824
# Epoch 374/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 51.5243 - categorical_accuracy: 0.3647
# Epoch 375/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 32.8476 - categorical_accuracy: 0.3294
# Epoch 376/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 57.5772 - categorical_accuracy: 0.3176
# Epoch 377/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 35.7113 - categorical_accuracy: 0.4000
# Epoch 378/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 76.5008 - categorical_accuracy: 0.2941
# Epoch 379/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 56.6342 - categorical_accuracy: 0.3294
# Epoch 380/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 42.9597 - categorical_accuracy: 0.3647
# Epoch 381/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 46.6624 - categorical_accuracy: 0.3529
# Epoch 382/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 26.3893 - categorical_accuracy: 0.2824
# Epoch 383/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 18.9463 - categorical_accuracy: 0.3647
# Epoch 384/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 41.0148 - categorical_accuracy: 0.2941
# Epoch 385/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 29.4874 - categorical_accuracy: 0.2824
# Epoch 386/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 35.4553 - categorical_accuracy: 0.4000
# Epoch 387/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 30.7548 - categorical_accuracy: 0.2706
# Epoch 388/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 13.5967 - categorical_accuracy: 0.2353
# Epoch 389/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 6.6713 - categorical_accuracy: 0.2941
# Epoch 390/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 23.3956 - categorical_accuracy: 0.3647
# Epoch 391/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 17.1839 - categorical_accuracy: 0.3529
# Epoch 392/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 24.9197 - categorical_accuracy: 0.3412
# Epoch 393/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 31.7026 - categorical_accuracy: 0.3529
# Epoch 394/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 39.0336 - categorical_accuracy: 0.2588
# Epoch 395/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 43.1647 - categorical_accuracy: 0.3059
# Epoch 396/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 33.1400 - categorical_accuracy: 0.3529
# Epoch 397/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 34.9862 - categorical_accuracy: 0.3059
# Epoch 398/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 27.9375 - categorical_accuracy: 0.3294
# Epoch 399/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 47.6769 - categorical_accuracy: 0.3176
# Epoch 400/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 25.3696 - categorical_accuracy: 0.3059
# Epoch 401/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 44.0490 - categorical_accuracy: 0.3176
# Epoch 402/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 22.2037 - categorical_accuracy: 0.4118
# Epoch 403/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 22.6666 - categorical_accuracy: 0.3059
# Epoch 404/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 35.1105 - categorical_accuracy: 0.3176
# Epoch 405/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 38.1046 - categorical_accuracy: 0.2471
# Epoch 406/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 70.3844 - categorical_accuracy: 0.3294
# Epoch 407/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 24.6847 - categorical_accuracy: 0.3647
# Epoch 408/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 58.0324 - categorical_accuracy: 0.3529
# Epoch 409/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 51.1674 - categorical_accuracy: 0.2706
# Epoch 410/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 37.8502 - categorical_accuracy: 0.3176
# Epoch 411/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 18.9908 - categorical_accuracy: 0.4706
# Epoch 412/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 45.0021 - categorical_accuracy: 0.3765
# Epoch 413/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 37.0643 - categorical_accuracy: 0.2824
# Epoch 414/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 12.1169 - categorical_accuracy: 0.3176
# Epoch 415/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 17.5466 - categorical_accuracy: 0.3765
# Epoch 416/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 23.0019 - categorical_accuracy: 0.3176
# Epoch 417/2000
# 3/3 [==============================] - 0s 49ms/step - loss: 26.3689 - categorical_accuracy: 0.4000
# Epoch 418/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 29.8707 - categorical_accuracy: 0.3059
# Epoch 419/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 19.0116 - categorical_accuracy: 0.4235
# Epoch 420/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 23.5623 - categorical_accuracy: 0.3176
# Epoch 421/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 23.8663 - categorical_accuracy: 0.3647
# Epoch 422/2000
# ...
# Epoch 1861/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 1862/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 1863/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 1864/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 1865/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 1866/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 1867/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0037 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0017 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
#-----------------------------
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
actions[np.argmax(res[2])]
# Out:
# 'What'

# %%
actions[(y_test[0])]
# Out:
# array(['thank you', 'hello', 'thank you'], dtype='<U9')

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'hello'

# %%
model.save('action.h5')

# %%
model.load_weights('action.h5')

# %%
#----------------------------------------------
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[4, 1],
#         [0, 0]],
#
#        [[2, 0],
#         [1, 2]],
#
#        [[3, 0],
#         [0, 2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.8

# %%
#-------------------------------------------------
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# plt.figure(figsize=(18,18))
# plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24624\104962489.py in <module>
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# NameError: name 'image' is not defined

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, resultsq

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
#-------------------------------------------------------
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.3, min_tracking_confidence=0.2) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24624\2236089118.py in <module>
#      15
#      16         # Make detections
# ---> 17         image, results = mediapipe_detection(frame, holistic)
#      18         print(results)
#      19
#
# ~\AppData\Local\Temp\ipykernel_24624\3795214942.py in mediapipe_detection(image, model)
#       5     image.flags.writeable = True                   # Image is now writeable
#       6     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
# ----> 7     return image, resultsq
#
# NameError: name 'resultsq' is not defined
